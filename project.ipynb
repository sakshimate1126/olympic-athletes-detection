# %%
# Importing Libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Preprocessing and EDA of Olympic DataSet

# %%
df=pd.read_excel('Olympic_Athletes.xlsx')
df
# Out:
#                      Athlete  Age        Country  Year Closing Ceremony Date  \
# 0             Michael Phelps   23  United States  2008            2008-08-24
# 1             Michael Phelps   19  United States  2004            2004-08-29
# 2             Michael Phelps   27  United States  2012            2012-08-12
# 3           Natalie Coughlin   25  United States  2008            2008-08-24
# 4              Aleksey Nemov   24         Russia  2000            2000-10-01
# ..                       ...  ...            ...   ...                   ...
# 594        Anastasia Kuzmina   25       Slovakia  2010            2010-02-28
# 595         Christoph Sumann   34        Austria  2010            2010-02-28
# 596         Yevgeny Ustyugov   24         Russia  2010            2010-02-28
# 597            Olga Zaytseva   31         Russia  2010            2010-02-28
# 598  Florence Baverel-Robert   31         France  2006            2006-02-26
#
# ...

# %%
# First Five DataSet
df.head()
# Out:
#             Athlete  Age        Country  Year Closing Ceremony Date  \
# 0    Michael Phelps   23  United States  2008            2008-08-24
# 1    Michael Phelps   19  United States  2004            2004-08-29
# 2    Michael Phelps   27  United States  2012            2012-08-12
# 3  Natalie Coughlin   25  United States  2008            2008-08-24
# 4     Aleksey Nemov   24         Russia  2000            2000-10-01
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 0    Swimming            8              0              0             8
# 1    Swimming            6              0              2             8
# 2    Swimming            4              2              0             6
# 3    Swimming            1              2              3             6
# 4  Gymnastics            2              1              3             6

# %%
# Last five Dataset
df.tail()
# Out:
#                      Athlete  Age   Country  Year Closing Ceremony Date  \
# 594        Anastasia Kuzmina   25  Slovakia  2010            2010-02-28
# 595         Christoph Sumann   34   Austria  2010            2010-02-28
# 596         Yevgeny Ustyugov   24    Russia  2010            2010-02-28
# 597            Olga Zaytseva   31    Russia  2010            2010-02-28
# 598  Florence Baverel-Robert   31    France  2006            2006-02-26
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 594  Biathlon            1              1              0             2
# 595  Biathlon            0              2              0             2
# 596  Biathlon            1              0              1             2
# 597  Biathlon            1              1              0             2
# 598  Biathlon            1              0              1             2

# %% [markdown]
# #### Assessment of Data

# %%
# Checking rows and columns
df.shape
# Out:
# (599, 10)

# %%
df.size
# Out:
# 5990

# %%
# Checking information od data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Athlete                599 non-null    object
#  1   Age                    599 non-null    int64
#  2   Country                599 non-null    object
#  3   Year                   599 non-null    int64
#  4   Closing Ceremony Date  599 non-null    datetime64[ns]
#  5   Sport                  599 non-null    object
#  6   Gold Medals            599 non-null    int64
#  7   Silver Medals          599 non-null    int64
#  8   Bronze Medals          599 non-null    int64
#  9   Total Medals           599 non-null    int64
# dtypes: datetime64[ns](1), int64(6), object(3)
# memory usage: 46.9+ KB

# %%
df['Athlete']
# Out:
# 0               Michael Phelps
# 1               Michael Phelps
# 2               Michael Phelps
# 3             Natalie Coughlin
# 4                Aleksey Nemov
#                 ...
# 594          Anastasia Kuzmina
# 595           Christoph Sumann
# 596           Yevgeny Ustyugov
# 597              Olga Zaytseva
# 598    Florence Baverel-Robert
# Name: Athlete, Length: 599, dtype: object

# %%
df['Gold Medals'].unique()
# Out:
# array([8, 6, 4, 1, 2, 3, 0], dtype=int64)

# %%
df['Athlete'].unique()
# Out:
# array(['Michael Phelps', 'Natalie Coughlin', 'Aleksey Nemov',
#        'Alicia Coutts', 'Missy Franklin', 'Ryan Lochte',
#        'Allison Schmitt', 'Ian Thorpe', 'Dara Torres', 'Cindy Klassen',
#        'Nastia Liukin', 'Marit Bjørgen', 'Sun Yang', 'Kirsty Coventry',
#        'Libby Lenton-Trickett', 'Inge de Bruijn', 'Petria Thomas',
#        'Gary Hall Jr.', 'Michael Klim', "Susie O'Neill", 'Jenny Thompson',
#        'Pieter van den Hoogenband', 'An Hyeon-Su', 'Aliya Mustafina',
#        'Shawn Johnson', 'Dmitry Sautin', 'Leontien Zijlaard-van Moorsel',
#        'Petter Northug Jr.', 'Ole Einar Bjørndalen', 'Janica Kostelic',
#        'Nathan Adrian', 'Yannick Agnel', 'Brittany Elmslie',
#        'Matt Grevers', 'Ryosuke Irie', 'Cullen Jones',
#        'Ranomi Kromowidjojo', 'Camille Muffat', 'Mel Schlanger',
#        'Emily Seebohm', 'Rebecca Soni', 'Satomi Suzuki', 'Dana Vollmer',
#        'Alain Bernard', 'László Cseh Jr.', 'Margaret Hoelzer',
# ...

# %%
df['Athlete'].value_counts()
# Out:
# Katalin Kovács          4
# Valentina Vezzali       3
# Grant Hackett           3
# Ole Einar Bjørndalen    3
# Wu Minxia               3
#                        ..
# Magnus Moan             1
# Adam Pine               1
# Carolin Leonhardt       1
# Derek Parra             1
# Christine Magnuson      1
# Name: Athlete, Length: 493, dtype: int64

# %%
df['Gold Medals'].nunique()
# Out:
# 7

# %%
df['Gold Medals'].value_counts()
# Out:
# 1    245
# 0    197
# 2    128
# 3     24
# 4      3
# 6      1
# 8      1
# Name: Gold Medals, dtype: int64

# %%
df.T
# Out:
#                                        0                    1    \
# Athlete                     Michael Phelps       Michael Phelps
# Age                                     23                   19
# Country                      United States        United States
# Year                                  2008                 2004
# Closing Ceremony Date  2008-08-24 00:00:00  2004-08-29 00:00:00
# Sport                             Swimming             Swimming
# Gold Medals                              8                    6
# Silver Medals                            0                    0
# Bronze Medals                            0                    2
# Total Medals                             8                    8
#
#                                        2                    3    \
# Athlete                     Michael Phelps     Natalie Coughlin
# Age                                     27                   25
# Country                      United States        United States
# ...

# %%
df.loc[:,'Country']
# Out:
# 0      United States
# 1      United States
# 2      United States
# 3      United States
# 4             Russia
#            ...
# 594         Slovakia
# 595          Austria
# 596           Russia
# 597           Russia
# 598           France
# Name: Country, Length: 599, dtype: object

# %%
df.loc[(df.Age >=24)]
# Out:
#                      Athlete  Age        Country  Year Closing Ceremony Date  \
# 2             Michael Phelps   27  United States  2012            2012-08-12
# 3           Natalie Coughlin   25  United States  2008            2008-08-24
# 4              Aleksey Nemov   24         Russia  2000            2000-10-01
# 5              Alicia Coutts   24      Australia  2012            2012-08-12
# 7                Ryan Lochte   27  United States  2012            2012-08-12
# ..                       ...  ...            ...   ...                   ...
# 594        Anastasia Kuzmina   25       Slovakia  2010            2010-02-28
# 595         Christoph Sumann   34        Austria  2010            2010-02-28
# 596         Yevgeny Ustyugov   24         Russia  2010            2010-02-28
# 597            Olga Zaytseva   31         Russia  2010            2010-02-28
# 598  Florence Baverel-Robert   31         France  2006            2006-02-26
#
# ...

# %%
df.iloc[[0,3],[0,4]]
# Out:
#             Athlete Closing Ceremony Date
# 0    Michael Phelps            2008-08-24
# 3  Natalie Coughlin            2008-08-24

# %%
# Changing dtype
df['Country']=df['Country'].astype('category')
df
# Out:
#                      Athlete  Age        Country  Year Closing Ceremony Date  \
# 0             Michael Phelps   23  United States  2008            2008-08-24
# 1             Michael Phelps   19  United States  2004            2004-08-29
# 2             Michael Phelps   27  United States  2012            2012-08-12
# 3           Natalie Coughlin   25  United States  2008            2008-08-24
# 4              Aleksey Nemov   24         Russia  2000            2000-10-01
# ..                       ...  ...            ...   ...                   ...
# 594        Anastasia Kuzmina   25       Slovakia  2010            2010-02-28
# 595         Christoph Sumann   34        Austria  2010            2010-02-28
# 596         Yevgeny Ustyugov   24         Russia  2010            2010-02-28
# 597            Olga Zaytseva   31         Russia  2010            2010-02-28
# 598  Florence Baverel-Robert   31         France  2006            2006-02-26
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Athlete                599 non-null    object
#  1   Age                    599 non-null    int64
#  2   Country                599 non-null    category
#  3   Year                   599 non-null    int64
#  4   Closing Ceremony Date  599 non-null    datetime64[ns]
#  5   Sport                  599 non-null    object
#  6   Gold Medals            599 non-null    int64
#  7   Silver Medals          599 non-null    int64
#  8   Bronze Medals          599 non-null    int64
#  9   Total Medals           599 non-null    int64
# dtypes: category(1), datetime64[ns](1), int64(6), object(2)
# memory usage: 44.2+ KB

# %%
df.isnull()
# Out:
#      Athlete    Age  Country   Year  Closing Ceremony Date  Sport  \
# 0      False  False    False  False                  False  False
# 1      False  False    False  False                  False  False
# 2      False  False    False  False                  False  False
# 3      False  False    False  False                  False  False
# 4      False  False    False  False                  False  False
# ..       ...    ...      ...    ...                    ...    ...
# 594    False  False    False  False                  False  False
# 595    False  False    False  False                  False  False
# 596    False  False    False  False                  False  False
# 597    False  False    False  False                  False  False
# 598    False  False    False  False                  False  False
#
#      Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 0          False          False          False         False
# ...

# %%
df.isnull().sum()
# Out:
# Athlete                  0
# Age                      0
# Country                  0
# Year                     0
# Closing Ceremony Date    0
# Sport                    0
# Gold Medals              0
# Silver Medals            0
# Bronze Medals            0
# Total Medals             0
# dtype: int64

# %%
df.dropna()
# Out:
#                      Athlete  Age        Country  Year Closing Ceremony Date  \
# 0             Michael Phelps   23  United States  2008            2008-08-24
# 1             Michael Phelps   19  United States  2004            2004-08-29
# 2             Michael Phelps   27  United States  2012            2012-08-12
# 3           Natalie Coughlin   25  United States  2008            2008-08-24
# 4              Aleksey Nemov   24         Russia  2000            2000-10-01
# ..                       ...  ...            ...   ...                   ...
# 594        Anastasia Kuzmina   25       Slovakia  2010            2010-02-28
# 595         Christoph Sumann   34        Austria  2010            2010-02-28
# 596         Yevgeny Ustyugov   24         Russia  2010            2010-02-28
# 597            Olga Zaytseva   31         Russia  2010            2010-02-28
# 598  Florence Baverel-Robert   31         France  2006            2006-02-26
#
# ...

# %%
df.mean()
# Out:
# <ipython-input-25-c61f0c8f89b5>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# Age                25.166945
# Year             2006.140234
# Gold Medals         1.000000
# Silver Medals       0.762938
# Bronze Medals       0.594324
# Total Medals        2.357262
# dtype: float64

# %%
df.describe()
# Out:
#               Age         Year  Gold Medals  Silver Medals  Bronze Medals  \
# count  599.000000   599.000000   599.000000     599.000000     599.000000
# mean    25.166945  2006.140234     1.000000       0.762938       0.594324
# std      5.301496     4.193525     0.934296       0.758825       0.713488
# min     15.000000  2000.000000     0.000000       0.000000       0.000000
# 25%     22.000000  2003.000000     0.000000       0.000000       0.000000
# 50%     25.000000  2006.000000     1.000000       1.000000       0.000000
# 75%     28.000000  2010.000000     2.000000       1.000000       1.000000
# max     46.000000  2012.000000     8.000000       3.000000       3.000000
#
#        Total Medals
# count    599.000000
# mean       2.357262
# std        0.749075
# min        2.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        8.000000

# %%
df.corr(method='pearson')
# Out:
#                     Age      Year  Gold Medals  Silver Medals  Bronze Medals  \
# Age            1.000000  0.038811    -0.093518      -0.042521       0.028987
# Year           0.038811  1.000000    -0.016219      -0.011607       0.044755
# Gold Medals   -0.093518 -0.016219     1.000000      -0.405696      -0.353710
# Silver Medals -0.042521 -0.011607    -0.405696       1.000000      -0.323093
# Bronze Medals  0.028987  0.044755    -0.353710      -0.323093       1.000000
# Total Medals  -0.132107  0.010642     0.499385       0.199260       0.184023
#
#                Total Medals
# Age               -0.132107
# Year               0.010642
# Gold Medals        0.499385
# Silver Medals      0.199260
# Bronze Medals      0.184023
# Total Medals       1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True);

# %%
df.set_index('Age')
# Out:
#                      Athlete        Country  Year Closing Ceremony Date  \
# Age
# 23            Michael Phelps  United States  2008            2008-08-24
# 19            Michael Phelps  United States  2004            2004-08-29
# 27            Michael Phelps  United States  2012            2012-08-12
# 25          Natalie Coughlin  United States  2008            2008-08-24
# 24             Aleksey Nemov         Russia  2000            2000-10-01
# ..                       ...            ...   ...                   ...
# 25         Anastasia Kuzmina       Slovakia  2010            2010-02-28
# 34          Christoph Sumann        Austria  2010            2010-02-28
# 24          Yevgeny Ustyugov         Russia  2010            2010-02-28
# 31             Olga Zaytseva         Russia  2010            2010-02-28
# 31   Florence Baverel-Robert         France  2006            2006-02-26
#
#           Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# Age
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
sns.countplot(x=df['Age'],order=df['Age'].value_counts().index.sort_values())
plt.xlabel('Age',fontsize=30)
plt.ylabel('Total Medals',fontsize=30)
plt.title('Total Medals vs Age',fontsize=40);

# %%
plt.figure(figsize=(10,12))
plt.pie(df['Sport'].value_counts(),labels=df['Sport'].value_counts().index,autopct="%1.2f%%")
plt.title("sports")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.countplot(x=df['Country'],order=df['Country'].value_counts().index.sort_values(),palette='dark')
plt.xticks(rotation='vertical')
plt.xlabel('Country',fontsize=30)
plt.ylabel('Gold Medals',fontsize=30)
plt.title('Gold Medals vs Country',fontsize=40);

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.countplot(y=df['Athlete'],order=df['Athlete'].value_counts().index[0:10],palette='deep')

plt.xlabel('Total Medals',fontsize=12)
plt.ylabel('Athlete',fontsize=12)
plt.title('Athlete vs Total Medals ',fontsize=16);

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.countplot(y=df['Country'],order=df['Country'].value_counts().index[0:10],palette='magma')

plt.xlabel('Country',fontsize=30)
plt.ylabel('Age',fontsize=30)
plt.title('Age vs Country',fontsize=40);

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=df[df['Athlete']!=0]['Athlete'].value_counts().index[0:5],
           y=df['Athlete'].value_counts()[0:5],palette='CMRmap')
plt.xticks(rotation='vertical')
plt.xlabel('Athlete',fontsize=12)
plt.ylabel('Silver Medals',fontsize=12)
plt.title('Silver Medals vs Athlete',fontsize=14);

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
sns.lineplot(x=df['Age'],order=df['Age'].value_counts().index.sort_values())
plt.xlabel('Age',fontsize=30)
plt.ylabel('Total Medals',fontsize=30)
plt.title('Total Medals vs Age',fontsize=40);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-b3409afc39e6> in <module>
#       2 import seaborn as sns
#       3 plt.figure(figsize=(10,10))
# ----> 4 sns.lineplot(x=df['Age'],order=df['Age'].value_counts().index.sort_values())
#       5 plt.xlabel('Age',fontsize=30)
#       6 plt.ylabel('Total Medals',fontsize=30)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt  


profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year')
plt.xlabel('Month number')
plt.ylabel('Profit in dollar')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt  
import numpy as np
x =([ 0 , 2,  4,  6   , 8 ,  10  , 12])
y =([ 0, 4,  16, 36 , 64, 100, 144])
plt.plot(x,y)
plt.show()

# %%
 import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,1])plt.show()

# %%
 import matplotlib.pyplot as plt 
    
plt.plot([1,2,3],[4,5,1]) 
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.plot([1,2],[4,5]) 
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.plot([2,3],[5,1]) 
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.plot([1,3],[4,1]) 
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.plot([1,2,3],[4,5,1]) 
plt.show()
